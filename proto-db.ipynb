# %%
from nba_api.stats.static import players
from nba_api.stats.endpoints import playercareerstats

# %%
from nba_api.stats.endpoints import teamvsplayer

# %%
import sqlite3

try:
    sqliteConnection = sqlite3.connect('SQLite_Python.db')
    cursor = sqliteConnection.cursor()
    print("Database created and Successfully Connected to SQLite")

    sqlite_select_Query = "select sqlite_version();"
    cursor.execute(sqlite_select_Query)
    record = cursor.fetchall()
    print("SQLite Database Version is: ", record)
    cursor.close()

except sqlite3.Error as error:
    print("Error while connecting to sqlite", error)
# Out:
# Database created and Successfully Connected to SQLite
# SQLite Database Version is:  [('3.40.1',)]

# %%
player_dict = players.get_players()

# %%
haliburton= [player for player in player_dict if player['full_name']=='Tyrese Haliburton'][0]
haliburton_id = haliburton['id']
haliburton_id
# Out:
# 1630169

# %%
career = playercareerstats.PlayerCareerStats(player_id=haliburton_id)
res = career.get_data_frames()[0]
res
# Out:
#    PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
# 0    1630169   2020-21        00  1610612758               SAC        21.0
# 1    1630169   2021-22        00  1610612758               SAC        22.0
# 2    1630169   2021-22        00  1610612754               IND        22.0
# 3    1630169   2021-22        00           0               TOT        22.0
# 4    1630169   2022-23        00  1610612754               IND        22.0
#
#    GP  GS     MIN  FGM  ...  FT_PCT  OREB  DREB  REB  AST  STL  BLK  TOV   PF  \
# 0  58  20  1746.0  292  ...   0.857    39   134  173  309   77   28   92   83
# 1  51  51  1757.0  268  ...   0.837    39   160  199  379   86   34  115   71
# 2  26  26   938.0  162  ...   0.849    22    90  112  249   48   15   84   50
# 3  77  77  2694.0  430  ...   0.842    61   250  311  628  134   49  199  121
# 4  48  48  1605.0  345  ...   0.864    32   149  181  483   84   19  126   56
#
#     PTS
# 0   753
# 1   727
# 2   454
# ...

# %%
player_dict = players.get_players()

# %%
active_players = [player for player in player_dict if player['is_active']==True]
print(len(active_players), active_players[100:105])
# Out:
# 582 [{'id': 1629634, 'full_name': 'Brandon Clarke', 'first_name': 'Brandon', 'last_name': 'Clarke', 'is_active': True}, {'id': 203903, 'full_name': 'Jordan Clarkson', 'first_name': 'Jordan', 'last_name': 'Clarkson', 'is_active': True}, {'id': 1629651, 'full_name': 'Nic Claxton', 'first_name': 'Nic', 'last_name': 'Claxton', 'is_active': True}, {'id': 1629599, 'full_name': 'Amir Coffey', 'first_name': 'Amir', 'last_name': 'Coffey', 'is_active': True}, {'id': 1628381, 'full_name': 'John Collins', 'first_name': 'John', 'last_name': 'Collins', 'is_active': True}]

# %%
id_ = [player for player in player_dict if player['full_name']==name]
# Out:
# [{'id': 1630173,
#   'full_name': 'Precious Achiuwa',
#   'first_name': 'Precious',
#   'last_name': 'Achiuwa',
#   'is_active': True},
#  {'id': 203500,
#   'full_name': 'Steven Adams',
#   'first_name': 'Steven',
#   'last_name': 'Adams',
#   'is_active': True},
#  {'id': 1628389,
#   'full_name': 'Bam Adebayo',
#   'first_name': 'Bam',
#   'last_name': 'Adebayo',
#   'is_active': True},
#  {'id': 1630534,
#   'full_name': 'Ochai Agbaji',
#   'first_name': 'Ochai',
#   'last_name': 'Agbaji',
#   'is_active': True},
#  {'id': 1630583,
#   'full_name': 'Santi Aldama',
#   'first_name': 'Santi',
#   'last_name': 'Aldama',
#   'is_active': True},
#  {'id': 1629638,
#   'full_name': 'Nickeil Alexander-Walker',
#   'first_name': 'Nickeil',
#   'last_name': 'Alexander-Walker',
#   'is_active': True},
#  {'id': 1628960,
#   'full_name': 'Grayson Allen',
#   'first_name': 'Grayson',
#   'last_name': 'Allen',
#   'is_active': True},
#  {'id': 1628386,
#   'full_name': 'Jarrett Allen',
# ...

# %%
active_players_ids = [x['id'] for x in active_players]

# %%
res = [player for player in active_players if player['id']==1629651][0]
res['full_name']
# Out:
# 'Nic Claxton'

# %%
res = requests.get('https://api.the-odds-api.com/v4/sports/?apiKey=344f688e5e81f65ba37d33a8b55540a0&active=false')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 res = requests.get('https://api.the-odds-api.com/v4/sports/?apiKey=344f688e5e81f65ba37d33a8b55540a0&active=false')
#
# NameError: name 'requests' is not defined

# %%
res.json()
# Out:
# [{'key': 'americanfootball_nfl_super_bowl_winner',
#   'group': 'American Football',
#   'title': 'NFL Super Bowl Winner',
#   'description': 'Super Bowl Winner 2023/2024',
#   'active': True,
#   'has_outrights': True},
#  {'key': 'aussierules_afl',
#   'group': 'Aussie Rules',
#   'title': 'AFL',
#   'description': 'Aussie Football',
#   'active': True,
#   'has_outrights': False},
#  {'key': 'baseball_mlb_world_series_winner',
#   'group': 'Baseball',
#   'title': 'MLB World Series Winner',
#   'description': 'World Series Winner 2023',
#   'active': True,
#   'has_outrights': True},
#  {'key': 'basketball_euroleague',
#   'group': 'Basketball',
#   'title': 'Basketball Euroleague',
#   'description': 'Basketball Euroleague',
#   'active': True,
#   'has_outrights': False},
#  {'key': 'basketball_nba_championship_winner',
#   'group': 'Basketball',
#   'title': 'NBA Championship Winner',
#   'description': 'Championship Winner 2022/2023',
#   'active': True,
# ...

# %%
344f688e5e81f65ba37d33a8b55540a0
https://api.the-odds-api.com/v4/sports/?apiKey=344f688e5e81f65ba37d33a8b55540a0

# %%
import requests

# %%
res = requests.get('https://api.the-odds-api.com/v4/sports/americanfootball_nfl/odds/?apiKey=344f688e5e81f65ba37d33a8b55540a0&regions=us&markets=h2h,spreads&oddsFormat=american')

# %%
res = requests.get('https://api.the-odds-api.com/v4/sports/?apiKey=344f688e5e81f65ba37d33a8b55540a0')

# %%
/v4/sports/{sport}/odds/?apiKey={apiKey}&regions={regions}&markets={markets}

# %%
res = requests.get('https://api.the-odds-api.com/v4/sports/basketball_nba/odds/?apiKey=344f688e5e81f65ba37d33a8b55540a0&regions=us&markets=spreads')

# %%
res.json()
# Out:
# []

# %%
res = requests.get('https://api.the-odds-api.com/v4/sports/?apiKey=344f688e5e81f65ba37d33a8b55540a0&regions=us')

# %%
res = requests.get('https://api.the-odds-api.com/v4/sports/basketball_nba/odds/?apiKey=344f688e5e81f65ba37d33a8b55540a0&regions=us&markets=spreads')

# %%
res
# Out:
# <Response [200]>

# %%
res_json = res.json()
res_json
# Out:
# []

# %%
for i in range(len(res_json)):
    print(res_json[i]['key'])
# Out:
# americanfootball_nfl_super_bowl_winner
# aussierules_afl
# baseball_mlb_world_series_winner
# basketball_euroleague
# basketball_nba_championship_winner
# basketball_ncaab
# cricket_international_t20
# cricket_psl
# cricket_test_match
# golf_masters_tournament_winner
# golf_pga_championship_winner
# golf_the_open_championship_winner
# golf_us_open_winner
# icehockey_nhl
# icehockey_nhl_championship_winner
# icehockey_sweden_allsvenskan
# icehockey_sweden_hockey_league
# mma_mixed_martial_arts
# rugbyleague_nrl
# soccer_argentina_primera_division
# soccer_australia_aleague
# soccer_austria_bundesliga
# soccer_belgium_first_div
# soccer_chile_campeonato
# soccer_conmebol_copa_libertadores
# soccer_denmark_superliga
# soccer_efl_champ
# soccer_england_efl_cup
# soccer_england_league1
# soccer_england_league2
# soccer_epl
# soccer_fa_cup
# soccer_france_ligue_one
# soccer_france_ligue_two
# soccer_germany_bundesliga
# soccer_germany_bundesliga2
# soccer_germany_liga3
# ...

# %%
res.text
# Out:
# '[]\n'

# %%
res.headers
# Out:
# {'Date': 'Fri, 17 Feb 2023 14:22:10 GMT', 'Content-Type': 'application/json; charset=utf-8', 'Content-Length': '3', 'Connection': 'keep-alive', 'X-Requests-Remaining': '499', 'vary': 'Accept-Encoding', 'X-Requests-Used': '1', 'Apigw-Requestid': 'AfMO5jymoAMEYhw='}

# %%
res.text
# Out:
# '[]\n'
